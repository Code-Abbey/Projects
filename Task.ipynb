# %% [markdown]
# <a href="https://colab.research.google.com/github/Code-Abbey/Projects/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Load Dataset**

# %%
import numpy as np
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Dataset/Dataset.csv', encoding='ISO-8859-1')

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
# printing the first 5 rows of the dataframe
dataset.head()
# Out:
#   ï»¿vendor name Model Name   MYCT    MMIN     MMAX   CACH  CHMIN  CHMAX  \
# 0        adviser      32/60  125.0   256.0   6000.0  256.0   16.0  128.0
# 1         amdahl     470v/7   29.0  8000.0  32000.0   32.0    8.0   32.0
# 2         amdahl    470v/7a   29.0  8000.0  32000.0   32.0    8.0   32.0
# 3         amdahl    470v/7b   29.0  8000.0  32000.0   32.0    8.0   32.0
# 4         amdahl    470v/7c   29.0  8000.0  16000.0   32.0    8.0   16.0
#
#      PRP    ERP
# 0  198.0  199.0
# 1  269.0  253.0
# 2  220.0  253.0
# 3  172.0  253.0
# 4  132.0  132.0

# %%
# number of rows and columns
dataset.shape
# Out:
# (210, 10)

# %%
# statistical measures
dataset.describe()
# Out:
#               MYCT          MMIN          MMAX        CACH       CHMIN  \
# count   209.000000    209.000000    209.000000  209.000000  209.000000
# mean    203.822967   2867.980861  11796.153110   25.205742    4.698565
# std     260.262926   3878.742758  11726.564377   40.628722    6.816274
# min      17.000000     64.000000     64.000000    0.000000    0.000000
# 25%      50.000000    768.000000   4000.000000    0.000000    1.000000
# 50%     110.000000   2000.000000   8000.000000    8.000000    2.000000
# 75%     225.000000   4000.000000  16000.000000   32.000000    6.000000
# max    1500.000000  32000.000000  64000.000000  256.000000   52.000000
#
#             CHMAX          PRP          ERP
# count  209.000000   209.000000   209.000000
# mean    18.267943   105.622010    99.330144
# std     25.997318   160.830733   154.757102
# min      0.000000     6.000000    15.000000
# 25%      5.000000    27.000000    28.000000
# 50%      8.000000    50.000000    45.000000
# ...

# %%
# Dataset info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿vendor name  209 non-null    object
#  1   Model Name      209 non-null    object
#  2   MYCT            209 non-null    float64
#  3   MMIN            209 non-null    float64
#  4   MMAX            209 non-null    float64
#  5   CACH            209 non-null    float64
#  6   CHMIN           209 non-null    float64
#  7   CHMAX           209 non-null    float64
#  8   PRP             209 non-null    float64
#  9   ERP             209 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 16.5+ KB

# %%
# number of missing values in each column
dataset.isnull().sum()
# Out:
# ï»¿vendor name    1
# Model Name        1
# MYCT              1
# MMIN              1
# MMAX              1
# CACH              1
# CHMIN             1
# CHMAX             1
# PRP               1
# ERP               1
# dtype: int64

# %%
# Change the name of column 'ï»¿vendor name' to 'Vendor name'
dataset.rename(columns={'ï»¿vendor name': 'Vendor name'}, inplace=True)

# %%
print(dataset.columns)
# Out:
# Index(['Vendor name', 'Model Name', 'MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN',
#        'CHMAX', 'PRP', 'ERP'],
#       dtype='object')

# %% [markdown]
# **a) Create a Plot Similar to Figure 1**

# %%
#Import Libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#visualize the relationships between the variables.
sns.pairplot(dataset)
plt.suptitle('Scatterplot Matrix')
plt.show()

# %% [markdown]
# **b) Create a Correlation Matrix**

# %%
# Compute the correlation matrix
correlation_matrix = dataset.corr()

# Display the correlation matrix
print(correlation_matrix)

# visualization
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# <ipython-input-65-59169f61da7c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = dataset.corr()
#            MYCT      MMIN      MMAX      CACH     CHMIN     CHMAX       PRP  \
# MYCT   1.000000 -0.335642 -0.378561 -0.321000 -0.301090 -0.250502 -0.307099
# MMIN  -0.335642  1.000000  0.758157  0.534729  0.517189  0.266907  0.794931
# MMAX  -0.378561  0.758157  1.000000  0.537990  0.560513  0.527246  0.863004
# CACH  -0.321000  0.534729  0.537990  1.000000  0.582245  0.487846  0.662641
# CHMIN -0.301090  0.517189  0.560513  0.582245  1.000000  0.548281  0.608903
# CHMAX -0.250502  0.266907  0.527246  0.487846  0.548281  1.000000  0.605209
# PRP   -0.307099  0.794931  0.863004  0.662641  0.608903  0.605209  1.000000
# ERP   -0.288396  0.819292  0.901202  0.648620  0.610580  0.592156  0.966472
# ...

# %% [markdown]
# **c) Split the Data (62.5%-37.5% Split)**

# %%
from sklearn.model_selection import train_test_split

# Define features and target
X = dataset[['MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX']]
y = dataset['PRP']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.375, random_state=42)

# %% [markdown]
# **d) Perform Linear Regression**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Assuming 'dataset' is your pandas DataFrame
# First, handle missing values or incorrect data types
dataset.dropna(inplace=True)  # or use dataset.fillna(method)
dataset = dataset.apply(pd.to_numeric, errors='coerce')

# Define features and target
features = ['MYCT', 'MMIN', 'MMAX', 'CACH', 'CHMIN', 'CHMAX']
target = 'PRP'

X = dataset[features]
y = dataset[target]

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.375, random_state=42)

# Create and train the model
model = LinearRegression()
model.fit(X_train, y_train)

# Predict on training and test sets
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Calculate R² for training and test sets
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

print(f'R² for Training Data: {r2_train}')
print(f'R² for Test Data: {r2_test}')
# Out:
# R² for Training Data: 0.9060763306553475
# R² for Test Data: 0.7469994668249843

# %% [markdown]
# **e) Calculate Correlation Value Between y and y_predicted (Test Set)**

# %%
import numpy as np

# Calculate the correlation
correlation_test = np.corrcoef(y_test, y_test_pred)[0, 1]
print(f'Correlation between actual and predicted values (test set): {correlation_test}')
# Out:
# Correlation between actual and predicted values (test set): 0.9070613639198379

# %% [markdown]
# **f) Plot y versus y_pred for Training and Test Data**

# %%
plt.figure(figsize=(12, 6))

# Plot for Training Data
plt.subplot(1, 2, 1)
plt.scatter(y_train, y_train_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Training Data: Actual vs Predicted')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=2)

# Plot for Test Data
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Test Data: Actual vs Predicted')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)

plt.tight_layout()
plt.show()
